# %%
import folium
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from imblearn.combine import SMOTETomek
from sklearn.metrics import confusion_matrix, recall_score, precision_score, f1_score, accuracy_score
from imblearn.pipeline import Pipeline, make_pipeline
import category_encoders as ce
from scipy.stats import ttest_ind
import plotly.graph_objs as go
import plotly.express as px

# %%
from sklearn.preprocessing import LabelEncoder
from imblearn.under_sampling import TomekLinks
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from math import radians, sin, cos, sqrt, atan2
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.metrics import classification_report
from sklearn import metrics
import warnings
import pandas as pd
import seaborn as sns
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)
sns.set(font_scale=1.3)

# %%
import pandas as pd

# %%
train = pd.read_csv('fraudTrain.csv').drop('Unnamed: 0', axis=1)
test = pd.read_csv('fraudTest.csv').drop('Unnamed: 0', axis=1)

# %%
data = pd.concat([train, test]).reset_index().drop(columns='index')

del train
del test

# %%
#Data Understanding
data.columns
# Out:
# Index(['trans_date_trans_time', 'cc_num', 'merchant', 'category', 'amt',
#        'first', 'last', 'gender', 'street', 'city', 'state', 'zip', 'lat',
#        'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time', 'merch_lat',
#        'merch_long', 'is_fraud'],
#       dtype='object')

# %%
data.head(2)
# Out:
#   trans_date_trans_time            cc_num                         merchant  \
# 0   2019-01-01 00:00:18  2703186189652095       fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322  fraud_Heller, Gutmann and Zieme
#
#       category     amt      first   last gender                        street  \
# 0     misc_net    4.97   Jennifer  Banks      F                561 Perry Cove
# 1  grocery_pos  107.23  Stephanie   Gill      F  43039 Riley Greens Suite 393
#
#              city state    zip      lat      long  city_pop  \
# 0  Moravian Falls    NC  28654  36.0788  -81.1781      3495
# 1          Orient    WA  99160  48.8878 -118.2105       149
#
#                                  job         dob  \
# 0          Psychologist, counselling  1988-03-09
# 1  Special educational needs teacher  1978-06-21
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# 0  0b242abb623afc578575680df30655b9  1325376018  36.011293  -82.048315
# ...

# %%
data.shape
# Out:
# (1852394, 22)

# %%
info = pd.DataFrame(index=data.columns, columns=['Dtype', 'Unique Numbers'])
info['Dtype'] = data.dtypes
info['Unique Numbers'] = data.nunique()
info['Description'] = ['Transaction date and time', 'Credit card number', 'Merchant name',
                       'Different transaction categories', 'The amount of financial activities',
                       'First name', 'Last name', 'Gender', 'Street', 'City', 'State', 'Zipcode',
                       'Customer latitude', 'Customer longitude', 'Population of city', 'Job',
                       'Date of birth', 'Transaction ID', 'Unix Time', 'Merchant latitude',
                       'Merchant longitude', 'Fraud or not (Target)']

# %%
info
# Out:
#                          Dtype  Unique Numbers  \
# trans_date_trans_time   object         1819551
# cc_num                   int64             999
# merchant                object             693
# category                object              14
# amt                    float64           60616
# first                   object             355
# last                    object             486
# gender                  object               2
# street                  object             999
# city                    object             906
# state                   object              51
# zip                      int64             985
# lat                    float64             983
# long                   float64             983
# city_pop                 int64             891
# job                     object             497
# dob                     object             984
# trans_num               object         1852394
# unix_time                int64         1819583
# ...

# %%
print('Duplicated Values:', data.duplicated().sum())
# Out:
# Duplicated Values: 0

# %%
print('Null Values:', data.isna().sum().sum())
# Out:
# Null Values: 0

# %%
info['Dtype'].value_counts()
# Out:
# Dtype
# object     12
# int64       5
# float64     5
# Name: count, dtype: int64

# %%
#Data cleaning and feature engineering
#Coloumn Removal
#Discretization
#Creating new features
#Feature extraction
#Merging first and last name
data['full_name'] = data['first'] + ' ' + data['last']

# %%
#Removing unnecessary columns
data.drop(['first', 'last', 'trans_num', 'unix_time'], axis=1, inplace=True)

# %%
#Convert to datetime to extract new info
data['trans_date_trans_time'] = pd.to_datetime(data['trans_date_trans_time'])

# %%
data['year'] = data['trans_date_trans_time'].dt.year
data['month'] = data['trans_date_trans_time'].dt.month
data['day'] = data['trans_date_trans_time'].dt.day
data['hour'] = data['trans_date_trans_time'].dt.hour
data['day_of_week'] = data['trans_date_trans_time'].dt.day_name()
data['is_weekend'] = (data['trans_date_trans_time'].dt.weekday // 5).map({0: 'No', 1: 'Yes'})

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
data['month'] = data['month'].apply(lambda x: months[x - 1])

# %%
#what to do with credit card number?
def get_credit_card_type(card_number):
    card_number = str(card_number)
    if card_number[0] == '4':
        return 'Visa'
    elif card_number[0] == '5' or card_number[0] == '2':
        return 'MasterCard'
    elif card_number[0] == '3':
        return 'American Express'
    elif card_number[0] == '6':
        return 'Discover'
    else:
        return 'Unknown'

# %%
#Credit card type
data['cc_type'] = data['cc_num'].apply(get_credit_card_type)

# %%
#Analyzing the frequency of transactions
freq = data['cc_num'].value_counts()

# %%
data['cc_freq'] = data['cc_num'].apply(lambda x: freq[x])

# %%
#We can calculate time differences between each transaction for each credit card to check sudden spikes
df = data.copy()

# %%
df.sort_values(by=['cc_num', 'trans_date_trans_time'], inplace=True)
grouped = df.groupby('cc_num')
df['time_difference'] = grouped['trans_date_trans_time'].diff()
df['time_difference_seconds'] = df['time_difference'].dt.total_seconds().fillna(0)
df.drop(['time_difference'], axis=1, inplace=True)

# %%
data['time_diff'] = df.sort_index()['time_difference_seconds']

# %%
del df

# %%
#Cleaning some features
data['category'] = data['category'].apply(lambda x: x.title().replace('_', ' '))

# %%
data['gender'] = data['gender'].map({'F': 'Female', 'M': 'Male'})

# %%
#Define address
data['address'] = data['street'] + ', ' + data['city'] + ', ' + data['state'] + ' ' + data['zip'].apply(str)

# %%
# Calculate the distance in km between customer coordinates and merchant coordinates
def haversine(lat1, lon1, lat2, lon2):
    from math import radians, sin, cos, sqrt, atan2
    
    # Radius of the Earth in kilometers
    R = 6371
    dlat = radians(lat2 - lat1)
    dlon = radians(lon2 - lon1)
    a = sin(dlat / 2) ** 2 + cos(radians(lat1)) * cos(radians(lat2)) * sin(dlon / 2) ** 2
    distance = 2 * R * atan2(sqrt(a), sqrt(1 - a))
    return distance

# %%
data['distance'] = data.apply(lambda row: haversine(row['lat'], row['long'], row['merch_lat'], row['merch_long']), axis=1)

# %%
print(data.columns)
# Out:
# Index(['trans_date_trans_time', 'cc_num', 'merchant', 'category', 'amt',
#        'gender', 'street', 'city', 'state', 'zip', 'lat', 'long', 'city_pop',
#        'job', 'dob', 'merch_lat', 'merch_long', 'is_fraud', 'full_name',
#        'year', 'month', 'day', 'hour', 'day_of_week', 'is_weekend', 'cc_type',
#        'cc_freq', 'time_diff', 'address', 'distance'],
#       dtype='object')

# %%
data.drop(['lat', 'long', 'merch_lat', 'merch_long'], axis=1, inplace=True)

# %%
import numpy as np
data['dob'] = pd.to_datetime(data['dob'])
data['age'] = np.ceil((data['trans_date_trans_time'] - data['dob']).dt.days / 365).astype(int)
data.drop('trans_date_trans_time', axis=1, inplace=True)

# %%
# Now, you can drop the 'dob' column
data.drop('dob', axis=1, inplace=True)

# %%
data['age'].min()
# Out:
# 14

# %%
data['age'].max()
# Out:
# 97

# %%
def age_interval(age):
    if 14 <= age < 30:
        return '14 to 30'
    elif 30 <= age < 45:
        return '30 to 45'
    elif 45 <= age < 60:
        return '45 to 60'
    elif 60 <= age < 75:
        return '60 to 75'
    else:
        return 'Older than 75'

# %%
data['age_interval'] = data['age'].apply(age_interval)

# %%
data.head(2)
# Out:
#              cc_num                         merchant     category     amt  \
# 0  2703186189652095       fraud_Rippin, Kub and Mann     Misc Net    4.97
# 1      630423337322  fraud_Heller, Gutmann and Zieme  Grocery Pos  107.23
#
#    gender                        street            city state    zip  \
# 0  Female                561 Perry Cove  Moravian Falls    NC  28654
# 1  Female  43039 Riley Greens Suite 393          Orient    WA  99160
#
#    city_pop                                job  is_fraud       full_name  \
# 0      3495          Psychologist, counselling         0  Jennifer Banks
# 1       149  Special educational needs teacher         0  Stephanie Gill
#
#    year month  day  hour day_of_week is_weekend     cc_type  cc_freq  \
# 0  2019   Jan    1     0     Tuesday         No  MasterCard     2927
# 1  2019   Jan    1     0     Tuesday         No    Discover     4362
#
#    time_diff                                         address   distance  age  \
# ...

# %%
data.shape
# Out:
# (1852394, 26)

# %%
import plotly.express as px
#Target is imbalanced
target = data['is_fraud'].value_counts()
fig = px.pie(values=target.values, names=target.index, title='Target Distribution', width=300, height=300)
fig.show()

# %%
#Numerical features
selected_num = ['amt', 'city_pop', 'age', 'distance', 'time_diff']

# %%
data[selected_num].describe().T
# Out:
#                count          mean            std        min          25%  \
# amt        1852394.0     70.063567     159.253975   1.000000     9.640000
# city_pop   1852394.0  88643.674509  301487.618344  23.000000   741.000000
# age        1852394.0     46.794096      17.424007  14.000000    33.000000
# distance   1852394.0     76.111726      29.116970   0.022255    55.320087
# time_diff  1852394.0  30922.794614   45322.458627   0.000000  5686.000000
#
#                    50%           75%           max
# amt           47.45000     83.100000  2.894890e+04
# city_pop    2443.00000  20328.000000  2.906700e+06
# age           45.00000     58.000000  9.700000e+01
# distance      78.21638     98.509467  1.521172e+02
# time_diff  15680.00000  38115.000000  1.341471e+06

# %%
data[selected_num].hist(figsize=(10, 10), bins=20)
import matplotlib.pyplot as plt
plt.show()

# %%
def log_transform(x):
    if x == 0:
        return 0
    return np.log(x)

def plot_log(col):
    data[col].apply(log_transform).hist(bins=20)
    plt.title(col)
    plt.show()

# %%
plot_log('time_diff')

# %%
plot_log('amt')

# %%
plot_log('city_pop')

# %%
categorical_features = data.select_dtypes(include=['object']).columns.tolist()

# %%
data[categorical_features].nunique()
# Out:
# merchant        693
# category         14
# gender            2
# street          999
# city            906
# state            51
# job             497
# full_name       989
# month            12
# day_of_week       7
# is_weekend        2
# cc_type           5
# address         999
# age_interval      5
# dtype: int64

# %%
def cat_bar(col):
    df = data_frame=data[col].value_counts()
    s = df.sum()
    fig = px.bar(df / s * 100, title=col.title().replace('_', ' '), width=700, height=500)
    fig.update_layout(xaxis_title=col.title(), yaxis_title='Counts')
    fig.update_traces(texttemplate='%{y:.1f}%', textposition='outside')
    fig.show()

# %%
def top5_cat_bar(col):
    df = data_frame=data[col].value_counts()[:5]
    s = df.sum()
    fig = px.bar(df / s * 100, title='Top 5 ' + col.title().replace('_', ' '), width=700, height=500)
    fig.update_layout(xaxis_title=col.title(), yaxis_title='Counts')
    fig.update_traces(texttemplate='%{y:.1f}%', textposition='outside')
    fig.show()

# %%
cat_bar('age_interval')

# %%
cat_bar('category')

# %%
cat_bar('gender')

# %%
cat_bar('month')

# %%
cat_bar('day_of_week')

# %%
cat_bar('is_weekend')

# %%
cat_bar('cc_type')

# %%
top5_cat_bar('merchant')

# %%
top5_cat_bar('city')

# %%
top5_cat_bar('state')

# %%
top5_cat_bar('job')

# %%
def bivar(col, target):
    plt.figure(figsize=(8, 6))
    sns.barplot(x=data[col], y=data[target], order=data.groupby(col)[target].mean().sort_values(ascending=False).index)
    plt.title(target.title() + ' By ' + col.title(), fontsize=14, fontweight='bold')
    plt.yticks(fontsize=14)
    plt.show()

# %%
bivar('is_fraud', 'amt')

# %%
def stack_bar(target, col):
    cross_tab = pd.crosstab(data[col], data[target])
    cross_tab_long = cross_tab.reset_index().melt(id_vars=col, var_name=target, value_name='Count')
    fig = px.bar(cross_tab_long, x=col, y='Count', color=target, barmode='stack')
    fig.update_layout(title='Number of Records Per ' + col.title() + ' For Each ' + target.title(),
                      xaxis_title=col.title(), yaxis_title='Count')
    fig.show()

# %%
stack_bar('is_fraud', 'category')

# %%
stack_bar('is_fraud', 'is_weekend')

# %%
stack_bar('is_fraud', 'cc_type')

# %%
stack_bar('is_fraud', 'hour')

# %%
stack_bar('is_fraud', 'age_interval')

# %%
bivar('age_interval', 'amt')

# %%
bivar('cc_type', 'amt')

# %%
bivar('is_weekend', 'amt')

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x=data['job'], y=data['amt'], order=data.groupby('job')['amt'].mean().sort_values(ascending=False)[:5].index)
plt.title('Top 5 Jobs Per Amount of Transaction', fontsize=14, fontweight='bold')
plt.yticks(fontsize=14)
plt.xticks(rotation=45)
plt.show()

# %%
stack_bar('cc_type', 'age_interval')

# %%
selected_jobs = list(data['job'].value_counts()[:5].index)
col = 'job'
target = 'age_interval'
filtered = data[data['job'].isin(selected_jobs)]
cross_tab = pd.crosstab(filtered[col], filtered[target])
cross_tab_long = cross_tab.reset_index().melt(id_vars=col, var_name=target, value_name='Count')
fig = px.bar(cross_tab_long, x=col, y='Count', color=target, barmode='stack')
fig.update_layout(title='Number of Records Per ' + col.title() + ' For Each ' + target.title(),
                  xaxis_title=col.title(), yaxis_title='Count')
fig.show()

# %%
selected_jobs = list(data['job'].value_counts()[:5].index)
col = 'job'
target = 'gender'
filtered = data[data['job'].isin(selected_jobs)]
cross_tab = pd.crosstab(filtered[col], filtered[target])
cross_tab_long = cross_tab.reset_index().melt(id_vars=col, var_name=target, value_name='Count')
fig = px.bar(cross_tab_long, x=col, y='Count', color=target, barmode='stack')
fig.update_layout(title='Number of Records Per ' + col.title() + ' For Each ' + target.title(),
                  xaxis_title=col.title(), yaxis_title='Count')
fig.show()

# %%
plt.figure(figsize=(14, 7))
sns.lineplot(x=data['year'], y=data['amt'])
plt.title('Amount of Transaction in Years', fontsize=14, fontweight='bold')
plt.show()

# %%
# Select only numeric columns
numeric_data = data.select_dtypes(include='number')

# Calculate correlation matrix
correlation_matrix = numeric_data.corr()

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
from scipy import stats

def cramers_v(x, y):
    confusion_matrix = pd.crosstab(x, y)
    chi2, _, _, _ = stats.chi2_contingency(confusion_matrix)
    n = confusion_matrix.sum().sum()
    phi2 = chi2 / n
    r, k = confusion_matrix.shape
    phi2corr = max(0, phi2 - ((k - 1) * (r - 1)) / (n - 1))
    rcorr = r - ((r - 1) ** 2) / (n - 1)
    kcorr = k - ((k - 1) ** 2) / (n - 1)
    return np.sqrt(phi2corr / min((kcorr - 1), (rcorr - 1)))

# %%
data['target'] = data['is_fraud'].map({0: 'No', 1: 'Yes'})

# %%
numerical_features = data.select_dtypes(include=['float64', 'int64', 'int32'])
categorical_features = data.select_dtypes(include=['object'])

# %%
num_features = len(categorical_features.columns)
corr_matrix = pd.DataFrame(np.ones((num_features, num_features)), columns=categorical_features.columns,
                           index=categorical_features.columns)

# %%
for i in range(num_features):
    for j in range(i + 1, num_features):
        corr_matrix.iloc[i, j] = cramers_v(categorical_features.iloc[:, i], categorical_features.iloc[:, j])
        corr_matrix.iloc[j, i] = corr_matrix.iloc[i, j]

# %%
plt.figure(figsize=(15, 11))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Association Matrix')
plt.show()

# %%
# Convert non-numeric values to numeric or NaN
data_numeric = data.apply(pd.to_numeric, errors='coerce')

# Calculate correlation with 'is_fraud' column
num_corrs = data_numeric.corr()['is_fraud'].sort_values(ascending=False)[1:]

# %%
cat_corrs = corr_matrix['target'].sort_values(ascending=False)[1:]

# %%
target_corrs = pd.concat([num_corrs, cat_corrs]).sort_values(ascending=False)

# %%
target_corrs[target_corrs >= 0.05]
# Out:
# address      0.308197
# street       0.308197
# full_name    0.305365
# city         0.273621
# amt          0.209308
# job          0.160263
# category     0.067003
# merchant     0.066000
# dtype: float64

# %%
data.drop(['cc_num', 'merchant', 'street', 'city', 'state', 'zip', 'year', 'target'], axis=1, inplace=True)

# %%
data['gender'] = data['gender'].map({'Female': 0, 'Male': 1})
data['is_weekend'] = data['is_weekend'].map({'No': 0, 'Yes': 1})

# %%
skewed = ['amt', 'city_pop', 'time_diff']
data[skewed] = data[skewed].apply(np.log1p)

# %%
from sklearn.preprocessing import OrdinalEncoder

# Now you can use OrdinalEncoder
oe = OrdinalEncoder()

# %%
data[['age_interval']] = oe.fit_transform(data[['age_interval']])

# %%
def woe(df, columns, target_col):
    woe = ce.WOEEncoder()
    for col in columns:
        X = df[col]
        y = df[target_col]
        new_col_name = f"{col}_WOE"
        df[new_col_name] = woe.fit_transform(X, y)
    return df.drop(columns, axis=1)

# %%
remained = ['category', 'job', 'address', 'month', 'day_of_week', 'cc_type', 'full_name']

# %%
data = woe(data, remained, 'is_fraud')

# %%
data.head()
# Out:
#         amt  gender  city_pop  is_fraud  day  hour  is_weekend  cc_freq  \
# 0  1.786747       0  8.159375         0    1     0           0     2927
# 1  4.684259       0  5.010635         0    1     0           0     4362
# 2  5.398660       1  8.332068         0    1     0           0      735
# 3  3.828641       1  7.570443         0    1     0           0      743
# 4  3.760269       1  4.605170         0    1     0           0     2922
#
#    time_diff    distance  age  age_interval  category_WOE   job_WOE  \
# 0        0.0   78.597568   31           1.0      0.925860 -0.395861
# 1        0.0   30.212176   41           1.0      0.894448 -0.694779
# 2        0.0  108.206083   57           2.0     -0.872388  1.494655
# 3        0.0   95.673231   53           2.0     -0.238221  0.095702
# 4        0.0   77.556744   33           1.0     -0.613751 -0.085108
#
#    address_WOE  month_WOE  day_of_week_WOE  cc_type_WOE  full_name_WOE
# ...

# %%
X = data.drop('is_fraud', axis=1)
y = data['is_fraud']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
def train_rf(X_train, y_train, X_test, y_test):
    rf = RandomForestClassifier(max_depth=12, n_estimators=100, random_state=234)
    rf.fit(X_train, y_train)
    y_pred = rf.predict(X_test)
    recall = recall_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    return [accuracy, recall, precision, f1]

# %%
results = pd.DataFrame(columns=['Accuracy', 'Recall', 'Precision', 'F1'])

# %%
from sklearn.impute import SimpleImputer

# Initialize the imputer
imputer = SimpleImputer(strategy='mean')  # You can choose other strategies like 'median' or 'most_frequent'

# Fit the imputer on the training data
imputer.fit(X_train)

# Impute missing values in both training and testing data
X_train_imputed = imputer.transform(X_train)
X_test_imputed = imputer.transform(X_test)

# Now, you can proceed with training your RandomForestClassifier using the imputed data
result0 = train_rf(X_train_imputed, y_train, X_test_imputed, y_test)
result0
# Out:
# [0.9980214802998281,
#  0.6358557643473844,
#  0.9873817034700315,
#  0.7735557615075687]

# %%
results.loc['Without changes'] = result0

# %%
rus = RandomUnderSampler(sampling_strategy=0.1, random_state=19)

# %%
X_undersampled, y_undersampled = rus.fit_resample(X_train, y_train)

# %%
X_undersampled.shape
# Out:
# (84502, 18)

# %%
X_train.shape
# Out:
# (1481915, 18)

# %%
from sklearn.impute import SimpleImputer

# Initialize the imputer
imputer = SimpleImputer(strategy='mean')  # You can choose other strategies like 'median' or 'most_frequent'

# Fit the imputer on the training data
imputer.fit(X_train)

# Impute missing values in both training and testing data
X_train_imputed = imputer.transform(X_train)
X_test_imputed = imputer.transform(X_test)

# Now, you can proceed with training your RandomForestClassifier using the imputed data
result1 = train_rf(X_train_imputed, y_train, X_test_imputed, y_test)
result1
# Out:
# [0.9980214802998281,
#  0.6358557643473844,
#  0.9873817034700315,
#  0.7735557615075687]

# %%
results.loc['UnderSampling'] = result1

# %%
ros = RandomOverSampler(random_state=4)

# %%
X_oversampled, y_oversampled = ros.fit_resample(X_train, y_train)

# %%
X_oversampled.shape
# Out:
# (2948466, 18)

# %%
X_undersampled.shape
# Out:
# (84502, 18)

# %%
y_undersampled.value_counts()
# Out:
# is_fraud
# 0    76820
# 1     7682
# Name: count, dtype: int64

# %%
X_oversampled, y_oversampled = ros.fit_resample(X_undersampled, y_undersampled)

# %%
X_oversampled.shape
# Out:
# (153640, 18)

# %%
from sklearn.impute import SimpleImputer

# Initialize the imputer
imputer = SimpleImputer(strategy='mean')  # You can choose other strategies like 'median' or 'most_frequent'

# Fit the imputer on the training data
imputer.fit(X_train)

# Impute missing values in both training and testing data
X_train_imputed = imputer.transform(X_train)
X_test_imputed = imputer.transform(X_test)

# Now, you can proceed with training your RandomForestClassifier using the imputed data
result2 = train_rf(X_train_imputed, y_train, X_test_imputed, y_test)
result2
# Out:
# [0.9980214802998281,
#  0.6358557643473844,
#  0.9873817034700315,
#  0.7735557615075687]

# %%
results.loc['OverSampling'] = result2
# SMOTE-Tomek Links
#Let's create a pipeline for this method

# %%
pipeline = Pipeline([('sampling', RandomUnderSampler(sampling_strategy=0.1, random_state=19)),
                     ('smote_tomek', SMOTETomek(tomek=TomekLinks(sampling_strategy='majority'))),
                     ('classifier', RandomForestClassifier(max_depth=12, n_estimators=100, random_state=1919))])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('sampling',
#                  RandomUnderSampler(random_state=19, sampling_strategy=0.1)),
#                 ('smote_tomek',
#                  SMOTETomek(tomek=TomekLinks(sampling_strategy='majority'))),
#                 ('classifier',
#                  RandomForestClassifier(max_depth=12, random_state=1919))])

# %%
y_pred = pipeline.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# %%
result3 = [accuracy, recall, precision, f1]
result3
# Out:
# [0.9812836894938715,
#  0.8885448916408669,
#  0.20402843601895734,
#  0.33185584891115827]

# %%
results.loc['SMOTE-Tomek Links'] = result3

# %%
rf_b = RandomForestClassifier(max_depth=12, n_estimators=100, random_state=1, class_weight='balanced')

# %%
rf_b.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=12, random_state=1)

# %%
y_pred = rf_b.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# %%
result4 = [accuracy, recall, precision, f1]
result4
# Out:
# [0.991119604619965, 0.9200206398348814, 0.362545750305002, 0.5201283547257877]

# %%
results.loc['Class Weights'] = result4

# %%
results
# Out:
#                    Accuracy    Recall  Precision        F1
# Without changes    0.997957  0.622807   0.978913  0.761274
# UnderSampling      0.997957  0.622807   0.978913  0.761274
# OverSampling       0.997957  0.622807   0.978913  0.761274
# SMOTE-Tomek Links  0.981284  0.888545   0.204028  0.331856
# Class Weights      0.991120  0.920021   0.362546  0.520128

# %%
importances = rf_b.feature_importances_
sorted(importances)
# Out:
# [0.0006522791757673929,
#  0.0014927156153778068,
#  0.003303993155329462,
#  0.003795144234914982,
#  0.0042584331747732495,
#  0.005142922091928023,
#  0.005859897213055085,
#  0.006926241149083284,
#  0.008536578564057694,
#  0.00880600484478893,
#  0.010457102985755726,
#  0.01989783012632257,
#  0.038692170009967934,
#  0.038763762099430984,
#  0.05653469519039676,
#  0.1107353230353268,
#  0.19615721197670416,
#  0.4799876953570192]

# %%
forest_importances = pd.Series(importances, index=X_train.columns)
fig, ax = plt.subplots(figsize=(12, 5))
forest_importances.sort_values(ascending=False).plot.bar(ax=ax)
ax.set_ylabel("Feature Importance")
plt.show()

# %%
sns.histplot(x='amt', hue='is_fraud', bins=20, stat='probability',
             data=data[data['amt'] <= data['amt'].quantile(0.99)], common_norm=False)
plt.title('Amount of Money For Each Target')
plt.show()

# %%
sns.histplot(x='hour', hue='is_fraud', bins=20, stat='probability', data=data, common_norm=False)
plt.title('Customers in Each Hour')
plt.show()

# %%
less_info = ['is_weekend', 'cc_type_WOE', 'age_interval', 'day_of_week_WOE']

# %%
X_undersampled.drop(less_info, axis=1, inplace=True)
X_test.drop(less_info, axis=1, inplace=True)

# %%
models_results = pd.DataFrame(columns=['Recall', 'Precision', 'F1', 'AUC'])

# %%
def evaluate_model(target, predicted, y_score, can_auc=True):
    accuracy = accuracy_score(target, predicted)
    precision = precision_score(target, predicted)
    recall = recall_score(target, predicted)
    f1 = f1_score(target, predicted)
    confusion_matrix = metrics.confusion_matrix(target, predicted)
    cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix, display_labels=[False, True])
    cm_display.plot()
    plt.grid(False)
    plt.show()
    
    auc = np.NaN
    if can_auc:
        auc = metrics.roc_auc_score(target, y_score)
        fpr, tpr, threshold = roc_curve(target, y_score)
        plt.plot(fpr, tpr, label='Model', c='blue')
        plt.plot([0, 1], [0, 1], linestyle='--', c='yellow')
        plt.title("ROC Curve")
        plt.legend()
        plt.show()

    print('Accuracy:', accuracy.round(2))
    print('Precision:', precision.round(2))
    print('Recall:', recall.round(2))
    print('F1 Score:', f1.round(2))
    print('AUC:', auc)
    
    return [recall.round(2), precision.round(2), f1.round(2), auc]

# %%
def train_model(model, X_train, y_train, X_test, y_test, auc_plot=True, scale=True):
    if scale:
        ss = StandardScaler()
        X_train = ss.fit_transform(X_train)
        X_test = ss.fit_transform(X_test)
    
    model.fit(X_train, y_train)
    
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)
    
    y_score_train = np.NaN
    y_score_test = np.NaN
    if auc_plot:
        y_score_train = model.predict_proba(X_train)[:, 1]
        y_score_test = model.predict_proba(X_test)[:, 1]
    
    print('-------------- Training Evaluation --------------')
    models_results.loc[type(model).__name__ + ' Trainig'] = evaluate_model(y_train, y_pred_train,
                                                                           y_score_train, can_auc=auc_plot)
    print('--------------         END         --------------')
    print()
    print()
    print('-------------- Testing Evaluation --------------')
    models_results.loc[type(model).__name__ + ' Testing'] = evaluate_model(y_test, y_pred_test,
                                                                           y_score_test, can_auc=auc_plot)
    print('--------------         END         --------------')

# %%
print('X Train:', X_undersampled.shape)
print('X Test:', X_test.shape)
# Out:
# X Train: (84843, 14)
# X Test: (370479, 14)

# %%
print('y Train:', y_undersampled.shape)
print('y Test:', y_test.shape)
# Out:
# y Train: (84843,)
# y Test: (370479,)

# %%
rf = RandomForestClassifier(random_state=2020)
train_model(rf, X_undersampled, y_undersampled, X_test, y_test, scale=False)
# Out:
# -------------- Training Evaluation --------------
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# AUC: 1.0
# --------------         END         --------------
#
#
# -------------- Testing Evaluation --------------
# Accuracy: 1.0
# Precision: 0.67
# Recall: 0.89
# F1 Score: 0.76
# AUC: 0.9946296195908813
# --------------         END         --------------

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression(random_state=2020)
train_model(lr, X_undersampled, y_undersampled, X_test, y_test, scale=False)
# Out:
# -------------- Training Evaluation --------------
# Accuracy: 0.95
# Precision: 0.87
# Recall: 0.52
# F1 Score: 0.65
# AUC: 0.8768923874047578
# --------------         END         --------------
#
#
# -------------- Testing Evaluation --------------
# Accuracy: 0.99
# Precision: 0.25
# Recall: 0.51
# F1 Score: 0.33
# AUC: 0.874992581196863
# --------------         END         --------------

# %%
plt.scatter(X_undersampled.iloc[:, 0], X_undersampled.iloc[:, 1], c=y_undersampled,
            cmap=plt.cm.Paired, edgecolors='k', marker='o', s=100, label='Data Points')
ax = plt.gca()
xlim = ax.get_xlim()
xx = np.linspace(xlim[0], xlim[1], 10)
decision_boundary = -(lr.coef_[0, 0] * xx + lr.intercept_) / lr.coef_[0, 1]
plt.plot(xx, decision_boundary, color='red', linestyle='--', label='Decision Boundary')
plt.title('Logistic Regression Decision Boundary')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb = GaussianNB()
train_model(nb, X_undersampled, y_undersampled, X_test, y_test, scale=False)
# Out:
# -------------- Training Evaluation --------------
# Accuracy: 0.91
# Precision: 0.48
# Recall: 0.36
# F1 Score: 0.42
# AUC: 0.8476484605432519
# --------------         END         --------------
#
#
# -------------- Testing Evaluation --------------
# Accuracy: 0.96
# Precision: 0.04
# Recall: 0.35
# F1 Score: 0.08
# AUC: 0.8431536333231163
# --------------         END         --------------

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier(random_state=2020)
train_model(dtree, X_undersampled, y_undersampled, X_test, y_test, scale=False)
# Out:
# -------------- Training Evaluation --------------
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# AUC: 1.0
# --------------         END         --------------
#
#
# -------------- Testing Evaluation --------------
# Accuracy: 0.99
# Precision: 0.34
# Recall: 0.92
# F1 Score: 0.49
# AUC: 0.9542475112493417
# --------------         END         --------------

# %%
rus = RandomUnderSampler(sampling_strategy=0.4, random_state=19)
SVM_X_train, SVM_y_train = rus.fit_resample(X_undersampled, y_undersampled)

# %%
from sklearn.svm import SVC

# %%
svm = SVC(random_state=2020)
train_model(svm, SVM_X_train, SVM_y_train, X_test, y_test, auc_plot=False)
# Out:
# -------------- Training Evaluation --------------
# Accuracy: 0.94
# Precision: 0.96
# Recall: 0.84
# F1 Score: 0.89
# AUC: nan
# --------------         END         --------------
#
#
# -------------- Testing Evaluation --------------
# Accuracy: 0.83
# Precision: 0.03
# Recall: 0.9
# F1 Score: 0.05
# AUC: nan
# --------------         END         --------------

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=3)
train_model(knn, SVM_X_train, SVM_y_train, X_test, y_test, auc_plot=False)
# Out:
# -------------- Training Evaluation --------------
# Accuracy: 0.96
# Precision: 0.95
# Recall: 0.9
# F1 Score: 0.92
# AUC: nan
# --------------         END         --------------
#
#
# -------------- Testing Evaluation --------------
# Accuracy: 0.87
# Precision: 0.04
# Recall: 0.89
# F1 Score: 0.07
# AUC: nan
# --------------         END         --------------

# %%
models_results.fillna(0, inplace=True)
models_results
# Out:
#                                 Recall  Precision    F1       AUC
# RandomForestClassifier Trainig    1.00       1.00  1.00  1.000000
# RandomForestClassifier Testing    0.89       0.67  0.76  0.994630
# LogisticRegression Trainig        0.52       0.87  0.65  0.876892
# LogisticRegression Testing        0.51       0.25  0.33  0.874993
# GaussianNB Trainig                0.36       0.48  0.42  0.847648
# GaussianNB Testing                0.35       0.04  0.08  0.843154
# DecisionTreeClassifier Trainig    1.00       1.00  1.00  1.000000
# DecisionTreeClassifier Testing    0.92       0.34  0.49  0.954248
# SVC Trainig                       0.84       0.96  0.89  0.000000
# SVC Testing                       0.90       0.03  0.05  0.000000
# KNeighborsClassifier Trainig      0.90       0.95  0.92  0.000000
# KNeighborsClassifier Testing      0.89       0.04  0.07  0.000000

# %%
trains = models_results[models_results.index.str.contains('Trainig')]

# %%
trains
# Out:
#                                 Recall  Precision    F1       AUC
# RandomForestClassifier Trainig    1.00       1.00  1.00  1.000000
# LogisticRegression Trainig        0.52       0.87  0.65  0.876892
# GaussianNB Trainig                0.36       0.48  0.42  0.847648
# DecisionTreeClassifier Trainig    1.00       1.00  1.00  1.000000
# SVC Trainig                       0.84       0.96  0.89  0.000000
# KNeighborsClassifier Trainig      0.90       0.95  0.92  0.000000

# %%
df_melted = trains.reset_index().melt(id_vars='index', var_name='Metric', value_name='Score')
sns.set(style="whitegrid", font_scale=1.3)
g = sns.catplot(x='index', y='Score', hue='Metric', data=df_melted, kind='bar', palette="muted", height=6, aspect=1.5)
g.set_axis_labels("Algorithms", "Score")
plt.title("Comparison of Training Metrics Across Algorithms")
plt.xticks(rotation=45)
plt.show()

# %%
tests = models_results[models_results.index.str.contains('Testing')]
tests
# Out:
#                                 Recall  Precision    F1       AUC
# RandomForestClassifier Testing    0.89       0.67  0.76  0.994630
# LogisticRegression Testing        0.51       0.25  0.33  0.874993
# GaussianNB Testing                0.35       0.04  0.08  0.843154
# DecisionTreeClassifier Testing    0.92       0.34  0.49  0.954248
# SVC Testing                       0.90       0.03  0.05  0.000000
# KNeighborsClassifier Testing      0.89       0.04  0.07  0.000000

# %%
df_melted = tests.reset_index().melt(id_vars='index', var_name='Metric', value_name='Score')
sns.set(style="whitegrid", font_scale=1.3)
g = sns.catplot(x='index', y='Score', hue='Metric', data=df_melted, kind='bar', palette="muted", height=6, aspect=1.5)
g.set_axis_labels("Algorithms", "Score")
plt.title("Comparison of Testing Metrics Across Algorithms")
plt.xticks(rotation=45)
plt.show()
